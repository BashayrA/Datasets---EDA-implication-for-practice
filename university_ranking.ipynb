# %% [markdown]
# #### After manually looking at the dataset:
#
# Note:
# The dataset is small and so I went through it fast and easy.
#
# Although I wish I knew an automated and more reliable method to do this kind of discovery!
#
# Correct me if I am wrong future me ;>
#
# What I discovered:
# - I found that University Rank is a categorical feature as some lower ranks are not exactly identified
# - These lower ranks are defined as: 1500 - 2000, which makes it impossible to transform it into a numerical feature
# - Transformation will manipulate the real data which can cause misleading results
#
# What I discovered after going through the data manually:
#
# - Some universities' ranks are missing and are labeled as: -
# - Some samples are missing so many features to the point that using them is no longer possible
# - I chose to drop sample with missing university name! -> no way to know about it or use the sample if i do not know what this university is right!
#
# Why am I being so much careful with the dataset?
# - Well because it is actually tiny to apply an effective machine learning model to it!
# - And I do not know what kind of applications to do with it! haha Yes I just go where the wind takes me to ;>

# %% [markdown]
# #### Import Libraries

# %%
## reading the dataset
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import kagglehub
import numpy
import shutil

# %% [markdown]
# #### Download Dataset From Kaggle Hub Into The Current Directory

# %%
# Download Dataset
path = kagglehub.dataset_download("alitaqi000/world-university-rankings-2023")

print(path)

# Move it to this directory 
shutil.copytree(path, ".", dirs_exist_ok=True)

# Remove the original file in the cache - clear cache
shutil.rmtree(path)
# Out:
# ...
# 100%|██████████| 70.2k/70.2k [00:00<00:00, 218kB/s]
# Extracting files...
# /home/momiji/.cache/kagglehub/datasets/alitaqi000/world-university-rankings-2023/versions/1

# %% [markdown]
# #### EDA - Discover data

# %%
# copy path to read data
path = './World University Rankings 2023.csv'

# read and explore dataset 
data1 = pd.read_csv(path)


print("Dataset Information: ")
## getteing a quick view

print(data1.info())

print()
print("Dataset Description: ")
## describing all data

print(data1.describe(include='all'))

print()
print("Dataset Shape: ")
# data's dimension - shape
print(data1.shape)
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2341 entries, 0 to 2340
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   University Rank              2341 non-null   object
#  1   Name of University           2233 non-null   object
#  2   Location                     2047 non-null   object
#  3   No of student                2209 non-null   object
#  4   No of student per staff      2208 non-null   float64
#  5   International Student        2209 non-null   object
#  6   Female:Male Ratio            2128 non-null   object
#  7   OverAll Score                1799 non-null   object
#  8   Teaching Score               1799 non-null   float64
#  9   Research Score               1799 non-null   float64
#  10  Citations Score              1799 non-null   float64
#  11  Industry Income Score        1799 non-null   float64
# ...

# %% [markdown]
# #### Missing Values - Handle missing values and drop useless samples

# %%
# check for missing values 

# drop samples with missing uni names

# WORK IN PROGRESS

# %% [markdown]
# #### Preprocessing Categorical Data That Should Be Numerical - Handle percentages that were stored as a string
# for example: '42%' will be processed as 0.42

# %%
# International Student is the percentage feature

# maybe it is better to include there precise number? instead of their percentage! -> feature engineer them 

# WORK IN PROGRESS

# %% [markdown]
# #### Preprocessing Numerical features - Are they duplicated?
#
# Overall Score feature can be a repetition of all the other recorded scores
# - How it is calculated?
# - If it is the avarage the for sure it is a replication
# - After all, keep it and check with Stat models if it useful to our model or not - since I do not know what to do eith the data yet!

# %%
# preprocess them by scaling normalizing handling missing values by using mean or mode?

# WORK IN PROGRESS

# %% [markdown]
# #### Encoding
